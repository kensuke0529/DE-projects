# %% [markdown]
# ### Data ingestion to Bronze

# %%
from pyspark.sql import functions as F

raw_root = "/Volumes/project/default/my_data_volume/weather/station=central_park/"

raw = (
    spark.read
      .format("csv")
      .option("header", "true")
      .option("inferSchema", "true")
      .option("basePath", raw_root)   
      .load(f"{raw_root}/year=*/month=*")
)

display(raw.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>tmin_c</th><th>tmax_c</th><th>tmin_f</th><th>tmax_f</th><th>prcp_mm</th><th>prcp_in</th><th>snow_mm</th><th>snow_in</th><th>snwd_mm</th><th>snwd_in</th><th>year</th><th>month</th></tr></thead><tbody><tr><td>2022-01-01</td><td>10.0</td><td>13.3</td><td>50.0</td><td>55.94</td><td>20.1</td><td>0.7913385826771655</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>2022</td><td>1</td></tr><tr><td>2022-01-02</td><td>2.8</td><td>15.0</td><td>37.04</td><td>59.0</td><td>1.0</td><td>0.03937007874015748</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>2022</td><td>1</td></tr><tr><td>2022-01-03</td><td>-5.5</td><td>2.8</td><td>22.1</td><td>37.04</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>2022</td><td>1</td></tr><tr><td>2022-01-04</td><td>-7.1</td><td>1.1</td><td>19.22</td><td>33.98</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>2022</td><td>1</td></tr><tr><td>2022-01-05</td><td>-0.5</td><td>8.3</td><td>31.1</td><td>46.94</td><td>5.8</td><td>0.2283464566929134</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>2022</td><td>1</td></tr><tr><td>2022-01-06</td><td>1.1</td><td>5.0</td><td>33.98</td><td>41.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>2022</td><td>1</td></tr><tr><td>2022-01-07</td><td>-3.8</td><td>1.1</td><td>25.16</td><td>33.98</td><td>9.7</td><td>0.38188976377952755</td><td>147.0</td><td>5.78740157480315</td><td>150.0</td><td>5.905511811023622</td><td>2022</td><td>1</td></tr><tr><td>2022-01-08</td><td>-6.6</td><td>-1.0</td><td>20.12</td><td>30.2</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>80.0</td><td>3.1496062992125986</td><td>2022</td><td>1</td></tr><tr><td>2022-01-09</td><td>-1.6</td><td>4.4</td><td>29.12</td><td>39.92</td><td>2.5</td><td>0.0984251968503937</td><td>0.0</td><td>0.0</td><td>80.0</td><td>3.1496062992125986</td><td>2022</td><td>1</td></tr><tr><td>2022-01-10</td><td>-4.3</td><td>4.4</td><td>24.26</td><td>39.92</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>2022</td><td>1</td></tr></tbody></table></div>

# %%
from pyspark.sql import functions as F

spark.sql('''
    DROP TABLE IF EXISTS project.taxi_bronze.weather_raw;
''')

bronze = (
    raw
    .withColumn("year", F.col("year").cast("int"))
    .withColumn("month", F.col("month").cast("int"))
    .withColumn("ingest_ts", F.current_timestamp())
)

(bronze.write
  .format("delta")
  .mode("overwrite")              
  .partitionBy("year", "month")
  .saveAsTable("project.taxi_bronze.weather_raw")
)

# %%
# %sql
SELECT year, month, COUNT(*) AS trips
FROM project.taxi_bronze.weather_raw
GROUP BY year, month
ORDER BY year, month;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th>month</th><th>trips</th></tr></thead><tbody><tr><td>2022</td><td>1</td><td>31</td></tr><tr><td>2022</td><td>2</td><td>28</td></tr></tbody></table></div>

# %%
weather_bronze = spark.table("project.taxi_bronze.weather_raw")

weather_silver = (
    weather_bronze
    .withColumn("date", F.to_date("date"))
    .withColumn("min_temp_c", F.col("tmin_c").cast("double"))
    .withColumn("max_temp_c", F.col("tmax_c").cast("double"))
    .withColumn("rain_mm", F.col("prcp_mm").cast("double"))
    .withColumn("snow_mm", F.col("snow_mm").cast("double"))

    # ---- WEATHER VALIDITY ----
    .filter(F.col("date").isNotNull())
    .filter(F.col("min_temp_c").between(-50, 50))
    .filter(F.col("max_temp_c").between(-50, 60))
    .filter(F.col("rain_mm") >= 0)
    .filter(F.col("snow_mm") >= 0)

    .withColumn("is_rain", F.col("rain_mm") > 0)
    .withColumn("is_snow", F.col("snow_mm") > 0)
)

weather_silver.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("project.taxi_silver.weather_daily")
